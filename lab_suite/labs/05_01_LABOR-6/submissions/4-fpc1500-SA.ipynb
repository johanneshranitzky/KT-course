# %% [markdown]
# # LABOR-3: R&S FPC1500 Spektrum-Analyzer (SCPI)
#
# ### Ziel der Uebung
#
# Ziel dieser Übung ist das Kennenlernen der Messtechnik mit einem professionellen Spektrum-Analyzer (**Rohde & Schwarz FPC1500**), der zusätzlich auch eine **Vector Network Analyzer (VNA)**-Funktion bietet.
#
#
# Die Kernaufgabe besteht darin, das Spektrum eines VFO-Signalgenerators zu untersuchen und dessen Leistung und Klirrfaktor zu bestimmen. Weiters soll das auf 1Hz Bandbreite normierte Signal-zu Rauschverhältnis $C/N_0$ ermittelt werden.
#
# Diese Programmieraufgabe soll vollständig mit Replay-Daten bearbeitet werden. Eine reale Messung soll mit dem nächstfolgenden Notebook für einen anderen Oszillator durchgeführt werden.
#
# Der FPC1500 wird über **Ethernet** mit dem PC verbunden. Im Praktikum wird dazu ein USB/Ethernet-Adapter verwendet, dessen IP-Konfiguration zur Analyzer-IP (**`192.168.1.10`**) passen muss. Die Datenuebertragung erfolgt über das **SCPI-Protokoll**.
#
# Damit soll das Gerät auch für weitere Uebungen ausserhalb der Laborzeiten (asynchrone Laborübung) einfach nutzbar sein.
#
# **Voraussetzung:** FPC1500 ist per Netzwerk erreichbar (IP und Port unten konfigurierbar).

# %% [markdown]
# ## Kurzinfo Bedienfeld:
#
#
#
# ### FPC1500 – Bedienung (einfach erklärt)
# - **Mode:**
#   Hier wählst du, *was* das Gerät sein soll:
#   **Spectrum Analyzer** (Spektrum messen) oder **Network Analyzer** (z. B. S11/S21 messen).
# - **Setup:**
#   Grundeinstellungen des Geräts, z. B. Netzwerk (IP-Adresse wie `192.168.1.10`).
# - **Meas:**
#   Auswahl der Messart innerhalb des aktuellen Modes.
# - **Freq / Span:**
#   Hier legst du den betrachteten Frequenzbereich fest:
#   entweder über **Start/Stop** oder über **Center/Span**.
# - **BW:**
#   - **RBW (Resolution Bandwidth):** bestimmt, wie fein das Spektrum aufgelöst wird.
#     Kleinere RBW = feinere Details, aber meist langsamere Messung.
#   - **VBW (Video Bandwidth):** glättet die Anzeige.
#     Kleinere VBW = ruhigeres Display, ohne die eigentliche Messphysik stark zu ändern.
# - **Ampt:**
#   Einstellung des **Reference Level** (oberer Pegelrand der Anzeige in dBm).
# - **Mkr / Mkr >:**
#   Marker einblenden und Marker-Funktionen nutzen, z. B.:
#   **Peak Search** (größtes Signal finden), **Marker to Center** usw.

# %%
import json
import socket
from pathlib import Path
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image, display
from matplotlib.widgets import Slider

try:
    get_ipython().run_line_magic("matplotlib", "widget")
except Exception:
    pass

# FPC1500: konfigurierbare Verbindung
FPC_IP = "192.168.1.10"
FPC_PORT = 5555
SOCKET_TIMEOUT = 5.0
SCREENSHOT_TIMEOUT = 10.0   # HCOP und Auslesen können deutlich länger als 5 s dauern
TRACE_READ_MAX_BYTES = 256 * 1024

# Offline-Workflow: bei REPLAY=True werden Messdaten aus JSON geladen
REPLAY = True
REPLAY_FILE = Path("recordings") / "1-fpc1500_sa_replay.json"

# Screenshots lokal speichern (Laborprotokoll, persistent)
SCREENSHOT_DIR = Path("screenshots")

def scpi_query(host: str, port: int, cmd: str, max_bytes: int = 4096) -> str:
    """SCPI-Befehl senden, Antwort lesen (bis Newline oder max_bytes)."""
    cmd = cmd.strip() + "\n"
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.settimeout(SOCKET_TIMEOUT)
    try:
        s.connect((host, port))
        s.sendall(cmd.encode())
        buf = b""
        while len(buf) < max_bytes:
            chunk = s.recv(8192)
            if not chunk:
                break
            buf += chunk
            if b"\n" in buf:
                break
        return buf.decode("utf-8", errors="replace").strip()
    finally:
        s.close()

def get_trace_data(host: str, port: int):
    """Frequenzachse (Hz), Trace-Werte (dBm) und RBW (Hz) vom FPC lesen.
    Returns (freqs, amps, rbw_hz) oder None.
    """
    try:
        trace_s = scpi_query(host, port, "TRAC:DATA? TRACE1", max_bytes=TRACE_READ_MAX_BYTES)
    except Exception:
        return None
    amps = []
    for part in trace_s.replace(",", " ").split():
        try:
            amps.append(float(part))
        except ValueError:
            continue
    if not amps:
        return None

    try:
        star_s = scpi_query(host, port, "FREQ:STAR?", max_bytes=256)
        stop_s = scpi_query(host, port, "FREQ:STOP?", max_bytes=256)
        freq_start = float(star_s.strip())
        freq_stop = float(stop_s.strip())
    except Exception:
        try:
            cent_s = scpi_query(host, port, "FREQ:CENT?", max_bytes=256)
            span_s = scpi_query(host, port, "FREQ:SPAN?", max_bytes=256)
            cent = float(cent_s.strip())
            span = float(span_s.strip())
            freq_start = cent - span / 2
            freq_stop = cent + span / 2
        except Exception:
            return None

    rbw_hz = None
    for rbw_cmd in ["BAND:RES?", "BANDwidth:RESolution?"]:
        try:
            rbw_hz = float(scpi_query(host, port, rbw_cmd, max_bytes=256).strip())
            break
        except Exception:
            continue

    n = len(amps)
    freqs = [freq_start + (freq_stop - freq_start) * i / max(1, n - 1) for i in range(n)]
    return (freqs, amps, rbw_hz)

def screenshot_save(host: str, port: int, filename: str = "screen.png") -> str | None:
    """Hardcopy auf dem Gerät auslösen und in MMEM speichern. Returns None bei Erfolg, sonst Fehlermeldung."""
    commands = ["HCOP:DEV:LANG PNG", "HCOP:DEST 'MMEM'", f"MMEM:NAME '{filename}'", "HCOP:IMM"]
    cmd = "\n".join(commands) + "\n"
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.settimeout(SCREENSHOT_TIMEOUT)
    try:
        s.connect((host, port))
        s.sendall(cmd.encode())
        buf = b""
        while len(buf) < 4096:
            try:
                chunk = s.recv(1024)
                if not chunk:
                    break
                buf += chunk
                if b"\n" in buf:
                    break
            except socket.timeout:
                break
        reply = buf.decode("utf-8", errors="replace").strip()
        if reply and "error" in reply.lower():
            return reply
        return None
    except Exception as e:
        return str(e)
    finally:
        s.close()


def save_replay_json(path: Path, data: dict):
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(data, indent=2), encoding="utf-8")


def load_replay_json(path: Path) -> dict:
    if not path.exists():
        raise FileNotFoundError(f"Replay-Datei nicht gefunden: {path}")
    return json.loads(path.read_text(encoding="utf-8"))


def screenshot_read(host: str, port: int, filename: str) -> bytes | None:
    """Datei vom Gerät (MMEM) lesen. MMEM:DATA? Antwort im IEEE 488.2-Blockformat. Returns PNG-Bytes oder None."""
    cmd = f"MMEM:DATA? '{filename}'\n"
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.settimeout(SCREENSHOT_TIMEOUT)
    try:
        s.connect((host, port))
        s.sendall(cmd.encode())
        buf = b""
        while b"#" not in buf and len(buf) < 1024:
            chunk = s.recv(256)
            if not chunk:
                return None
            buf += chunk
        if b"#" not in buf:
            return None
        start = buf.index(b"#")
        buf = buf[start:]
        if len(buf) < 2:
            buf += s.recv(2 - len(buf))
        n_digits = int(chr(buf[1]))
        if n_digits < 1 or n_digits > 9:
            return None
        while len(buf) < 2 + n_digits:
            buf += s.recv(2 + n_digits - len(buf))
        data_len = int(buf[2 : 2 + n_digits].decode())
        buf = buf[2 + n_digits :]
        while len(buf) < data_len:
            chunk = s.recv(min(65536, data_len - len(buf)))
            if not chunk:
                break
            buf += chunk
        return buf[:data_len] if len(buf) >= data_len else None
    except Exception:
        return None
    finally:
        s.close()

print("Konfiguration:", FPC_IP, "Port", FPC_PORT)
print(f"REPLAY={REPLAY}, Datei={REPLAY_FILE}")
# Out:
# Konfiguration: 192.168.1.10 Port 5555
# REPLAY=True, Datei=recordings/1-fpc1500_sa_replay.json

# %% [markdown]
# ### Verbindung testen (*IDN?)

# %%
if REPLAY:
    replay = load_replay_json(REPLAY_FILE)
    reply = replay.get("idn", "REPLAY")
    print("Gerät (Replay):", reply)
else:
    reply = scpi_query(FPC_IP, FPC_PORT, "*IDN?")
    print("Gerät:", reply if reply else "Keine Antwort (IP/Port prüfen, Gerät eingeschaltet?).")
# Out:
# Gerät (Replay): Rohde&Schwarz,FPC1500,1328.6660K03/102548,V1.50

# %% [markdown]
# ### Spektrum auslesen und plotten
#
# Trace-Daten (TRACE1) und Frequenzbereich werden per SCPI gelesen und als Betragsspektrum dargestellt.

# %%
if REPLAY:
    replay = load_replay_json(REPLAY_FILE)
    freqs = replay.get("freqs_hz", [])
    amps = replay.get("amps", [])
    rbw_hz = replay.get("rbw_hz", None)
else:
    result = get_trace_data(FPC_IP, FPC_PORT)
    if result is None:
        print("Trace-Daten konnten nicht gelesen werden.")
        freqs, amps, rbw_hz = [], [], None
    else:
        freqs, amps, rbw_hz = result
        save_replay_json(
            REPLAY_FILE,
            {
                "meta": {"type": "fpc1500_sa", "version": 2},
                "idn": reply,
                "freqs_hz": list(freqs),
                "amps": list(amps),
                "rbw_hz": rbw_hz,
            },
        )
        print("Replay gespeichert:", REPLAY_FILE)

if not freqs or not amps:
    print("Keine gueltigen Spektrumsdaten vorhanden.")
else:
    freq_hz = np.asarray(freqs, dtype=float)
    # hier sind die Leistungswerte in dBm   <----- !!!!!!!
    p_dbm = np.asarray(amps, dtype=float)
    
    freq_mhz = freq_hz / 1e6
    n = p_dbm.size

    fig = plt.figure(figsize=(12.0, 7.2), constrained_layout=False)
    gs = fig.add_gridspec(3, 1, height_ratios=[1.0, 0.10, 0.10], hspace=0.38)
    ax = fig.add_subplot(gs[0, 0])
    ax_m1 = fig.add_subplot(gs[1, 0])
    ax_m2 = fig.add_subplot(gs[2, 0])
    fig.subplots_adjust(top=0.90, bottom=0.14, left=0.08, right=0.98)

    ax.plot(freq_mhz, p_dbm, color="C0", linewidth=0.9)
    ax.set_xlabel("Frequenz (MHz)")
    ax.set_ylabel("Power in dBm")
    rbw_txt = f" | RBW={rbw_hz:.1f} Hz" if (rbw_hz is not None) else " | RBW=n/a"
    title_mode = "Replay" if REPLAY else "Live"
    ax.set_title(f"FPC1500 - Betragsspektrum (TRACE1, {title_mode})" + rbw_txt)
    ax.grid(True, alpha=0.3)

    idx1_0 = int(round(0.25 * (n - 1)))
    idx2_0 = int(round(0.75 * (n - 1)))

    m1, = ax.plot([freq_mhz[idx1_0]], [p_dbm[idx1_0]], "o", color="red", ms=7)
    m2, = ax.plot([freq_mhz[idx2_0]], [p_dbm[idx2_0]], "o", color="blue", ms=7)

    info_m1 = ax.text(0.01, 0.98, "", color="red", fontsize=10, ha="left", va="top", transform=ax.transAxes)
    info_m2 = ax.text(0.01, 0.92, "", color="blue", fontsize=10, ha="left", va="top", transform=ax.transAxes)
    info_delta = ax.text(0.01, 0.86, "", color="black", fontsize=10, ha="left", va="top", transform=ax.transAxes)
    info_power = ax.text(0.01, 0.80, "", color="0.2", fontsize=10, ha="left", va="top", transform=ax.transAxes)

    # Platzhalter: spektrale Gesamtleistung [dBm] aus den Werten vom numpy-array "p_dbm" im Marker-Intervall (in update_markers berechnen)
    spectral_power_dbm = None

    s1 = Slider(
        ax=ax_m1,
        label="Marker 1 (rot) - Sample-Index",
        valmin=0,
        valmax=n - 1,
        valinit=idx1_0,
        valstep=1,
        color="red",
    )
    s2 = Slider(
        ax=ax_m2,
        label="Marker 2 (blau) - Sample-Index",
        valmin=0,
        valmax=n - 1,
        valinit=idx2_0,
        valstep=1,
        color="blue",
    )
    ax_m1.set_facecolor("#f7f7f7")
    ax_m2.set_facecolor("#f7f7f7")

    def update_markers(_=None):
        global spectral_power_dbm
        i1 = int(s1.val)
        i2 = int(s2.val)

        m1.set_data([freq_mhz[i1]], [p_dbm[i1]])
        m2.set_data([freq_mhz[i2]], [p_dbm[i2]])

        df_hz = freq_hz[i2] - freq_hz[i1]
        df_khz = df_hz / 1000.0
        di = i2 - i1
        dp_db = p_dbm[i2] - p_dbm[i1]

        info_m1.set_text(
            f"M1 rot: f={freq_mhz[i1]:.6f} MHz | sample={i1} | P={p_dbm[i1]:.2f} dBm"
        )
        info_m2.set_text(
            f"M2 blau: f={freq_mhz[i2]:.6f} MHz | sample={i2} | P={p_dbm[i2]:.2f} dBm"
        )
        info_delta.set_text(
            f"Delta M2-M1: df={df_khz:+.3f} kHz | dSamples={di:+d} | dP={dp_db:+.2f} dB"
        )

        i_lo, i_hi = sorted((i1, i2))


        fig.canvas.draw_idle()

    s1.on_changed(update_markers)
    s2.on_changed(update_markers)
    update_markers()

    plt.show()

    print(f"{n} Punkte, Frequenzbereich {freq_mhz[0]:.4f} ... {freq_mhz[-1]:.4f} MHz")
    if rbw_hz is not None:
        print(f"RBW: {rbw_hz:.1f} Hz")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 1183 Punkte, Frequenzbereich 0.0000 ... 2500.0000 MHz
# RBW: 3000000.0 Hz

# %% [markdown]
# ## Aufgabe: Spektrale Gesamtleistung des Oszillator-Signals, Klirrfaktor und SNR (Oszillatorsignal versus geschätztem Noise-Floor).
#
# **Bestimme die gesamte spektrale Leistung des Oszillators.**
#
# - **Ermittle dessen Klirrfaktor.**
#
# - **Schätze die Lesitungsdichte des Noise-Floors (Durchschnittswert)**
#
# - **Berechne daraus das $C/N_0$**
#
# Erkläre den beabsichtigten Rechengang als **Kommentar**

# %%
# Die Aufgabe ist HIER umzusetzen.
# Rechengang:
# 1) Die gemessenen Pegelwerte p_dbm werden von dBm in lineare Leistung mW umgerechnet.
# 2) Der stärkste Peak wird als Grundschwingung des Oszillators interpretiert.
# 3) Die Harmonischen werden bei ganzzahligen Vielfachen der Grundfrequenz gesucht.
# 4) Um jeden gefundenen Peak wird ein kleines Frequenzfenster integriert.
# 5) Der Noise-Floor wird aus Bereichen ohne Signalpeaks gemittelt.
# 6) Daraus werden Gesamtleistung, Klirrfaktor und C/N0 berechnet.

if "freq_hz" not in globals() or "p_dbm" not in globals():
    raise RuntimeError("Bitte zuerst die Spektrums-Zelle ausführen, damit freq_hz und p_dbm vorhanden sind.")

freq_hz = np.asarray(freq_hz, dtype=float)
p_dbm = np.asarray(p_dbm, dtype=float)

# dBm -> mW
p_mw = 10 ** (p_dbm / 10)

# Frequenzauflösung
df_hz = np.mean(np.diff(freq_hz))

# RBW prüfen
if rbw_hz is None:
    rbw_hz = df_hz

# stärkster Peak = Grundschwingung
# stärkster Peak ohne DC-Anteil = Grundschwingung
min_fund_hz = 1e6   # alles unter 1 MHz ignorieren, damit 0 Hz/DC nicht als Peak genommen wird

valid_mask = freq_hz > min_fund_hz

if not np.any(valid_mask):
    raise RuntimeError("Keine gültigen Frequenzwerte über 1 MHz gefunden.")

valid_indices = np.where(valid_mask)[0]
idx_fund = valid_indices[np.argmax(p_dbm[valid_mask])]

f0_hz = freq_hz[idx_fund]
f0_mhz = f0_hz / 1e6

if f0_hz <= 0:
    raise RuntimeError("Grundfrequenz ist 0 Hz. Bitte DC-Anteil ausschließen.")

# Integrationsfenster um Peaks
window_hz = max(5 * rbw_hz, 5 * df_hz)

harmonic_powers_mw = []
harmonic_freqs_hz = []
peak_mask = np.zeros_like(p_dbm, dtype=bool)

max_harmonic = int(freq_hz[-1] / f0_hz)

for k in range(1, max_harmonic + 1):
    f_target = k * f0_hz

    if f_target < freq_hz[0] or f_target > freq_hz[-1]:
        continue

    idx = np.argmin(np.abs(freq_hz - f_target))

    # lokales Maximum in der Nähe der erwarteten Harmonischen suchen
    search_mask = np.abs(freq_hz - f_target) <= window_hz
    search_indices = np.where(search_mask)[0]

    if len(search_indices) == 0:
        continue

    local_idx = search_indices[np.argmax(p_dbm[search_indices])]
    f_peak = freq_hz[local_idx]

    # nur akzeptieren, wenn der Peak wirklich nahe beim Vielfachen liegt
    if abs(f_peak - f_target) > window_hz:
        continue

    # Leistung im Fenster um den Peak summieren
    int_mask = np.abs(freq_hz - f_peak) <= window_hz
    power_mw = np.sum(p_mw[int_mask])

    harmonic_freqs_hz.append(f_peak)
    harmonic_powers_mw.append(power_mw)
    peak_mask |= int_mask

harmonic_powers_mw = np.asarray(harmonic_powers_mw)
harmonic_freqs_hz = np.asarray(harmonic_freqs_hz)

# Noise-Floor aus Bereichen ohne Peaks
noise_values_dbm = p_dbm[~peak_mask]
noise_floor_dbm = np.mean(noise_values_dbm)

# Noise-Leistungsdichte auf 1 Hz normiert
noise_density_dbm_hz = noise_floor_dbm - 10 * np.log10(rbw_hz)

# Gesamtleistung des Oszillators
p_total_mw = np.sum(harmonic_powers_mw)
p_total_dbm = 10 * np.log10(p_total_mw)

# Grundschwingung und Oberwellen
p_fund_mw = harmonic_powers_mw[0]
p_harmonics_mw = np.sum(harmonic_powers_mw[1:])

# Klirrfaktor k = sqrt(P_Oberschwingungen / P_Grundschwingung)
klirrfaktor = np.sqrt(p_harmonics_mw / p_fund_mw)
klirrfaktor_percent = klirrfaktor * 100

# C/N0 mit C = Leistung der Grundschwingung
c_dbm = 10 * np.log10(p_fund_mw)
cn0_dbhz = c_dbm - noise_density_dbm_hz

print("Ergebnisse:")
print(f"Grundfrequenz f0:              {f0_mhz:.6f} MHz")
print(f"Leistung Grundschwingung C:    {c_dbm:.2f} dBm")
print(f"Gesamte Oszillatorleistung:    {p_total_dbm:.2f} dBm")
print(f"Noise-Floor:                   {noise_floor_dbm:.2f} dBm")
print(f"Noise-Leistungsdichte N0:      {noise_density_dbm_hz:.2f} dBm/Hz")
print(f"C/N0:                          {cn0_dbhz:.2f} dBHz")
print(f"Klirrfaktor:                   {klirrfaktor:.4f} = {klirrfaktor_percent:.2f} %")

print("\nGefundene Harmonische:")
for i, (f, p) in enumerate(zip(harmonic_freqs_hz, harmonic_powers_mw), start=1):
    print(f"{i}. Harmonische: {f/1e6:.6f} MHz, Leistung: {10*np.log10(p):.2f} dBm")

# Plot mit markierten Harmonischen
plt.figure(figsize=(12, 6))
plt.plot(freq_hz / 1e6, p_dbm, label="Spektrum")
plt.scatter(harmonic_freqs_hz / 1e6, 10 * np.log10(harmonic_powers_mw), color="red", label="Harmonische")
plt.axhline(noise_floor_dbm, linestyle="--", label="geschätzter Noise-Floor")
plt.xlabel("Frequenz in MHz")
plt.ylabel("Leistung in dBm")
plt.title("Spektrum mit Grundschwingung, Harmonischen und Noise-Floor")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Ergebnisse:
# Grundfrequenz f0:              2.115059 MHz
# Leistung Grundschwingung C:    18.20 dBm
# Gesamte Oszillatorleistung:    29.00 dBm
# Noise-Floor:                   nan dBm
# Noise-Leistungsdichte N0:      nan dBm/Hz
# C/N0:                          nan dBHz
# Klirrfaktor:                   3.3199 = 331.99 %
#
# Gefundene Harmonische:
# 1. Harmonische: 0.000000 MHz, Leistung: 18.20 dBm
# 2. Harmonische: 0.000000 MHz, Leistung: 18.20 dBm
# 3. Harmonische: 0.000000 MHz, Leistung: 18.20 dBm
# 4. Harmonische: 0.000000 MHz, Leistung: 18.20 dBm
# 5. Harmonische: 0.000000 MHz, Leistung: 18.20 dBm
# 6. Harmonische: 0.000000 MHz, Leistung: 18.20 dBm
# 7. Harmonische: 0.000000 MHz, Leistung: 18.20 dBm
# 8. Harmonische: 2.115059 MHz, Leistung: 18.20 dBm
# 9. Harmonische: 4.230118 MHz, Leistung: 18.20 dBm
# 10. Harmonische: 6.345178 MHz, Leistung: 18.20 dBm
# 11. Harmonische: 10.575296 MHz, Leistung: 18.20 dBm
# 12. Harmonische: 10.575296 MHz, Leistung: 18.20 dBm
# 13. Harmonische: 23.265651 MHz, Leistung: -53.33 dBm
# 14. Harmonische: 23.265651 MHz, Leistung: -53.33 dBm
# 15. Harmonische: 23.265651 MHz, Leistung: -53.33 dBm
# 16. Harmonische: 23.265651 MHz, Leistung: -53.33 dBm
# 17. Harmonische: 23.265651 MHz, Leistung: -53.33 dBm
# 18. Harmonische: 23.265651 MHz, Leistung: -53.33 dBm
# 19. Harmonische: 25.380711 MHz, Leistung: -53.44 dBm
# 20. Harmonische: 27.495770 MHz, Leistung: -53.62 dBm
# 21. Harmonische: 40.186125 MHz, Leistung: -54.43 dBm
# 22. Harmonische: 40.186125 MHz, Leistung: -54.43 dBm
# 23. Harmonische: 40.186125 MHz, Leistung: -54.43 dBm
# 24. Harmonische: 40.186125 MHz, Leistung: -54.43 dBm
# 25. Harmonische: 40.186125 MHz, Leistung: -54.43 dBm
# 26. Harmonische: 40.186125 MHz, Leistung: -54.43 dBm
# 27. Harmonische: 50.761421 MHz, Leistung: -54.85 dBm
# 28. Harmonische: 74.027073 MHz, Leistung: -54.98 dBm
# 29. Harmonische: 74.027073 MHz, Leistung: -54.98 dBm
# 30. Harmonische: 74.027073 MHz, Leistung: -54.98 dBm
# 31. Harmonische: 74.027073 MHz, Leistung: -54.98 dBm
# 32. Harmonische: 74.027073 MHz, Leistung: -54.98 dBm
# 33. Harmonische: 74.027073 MHz, Leistung: -54.98 dBm
# 34. Harmonische: 74.027073 MHz, Leistung: -54.98 dBm
# 35. Harmonische: 74.027073 MHz, Leistung: -54.98 dBm
# 36. Harmonische: 74.027073 MHz, Leistung: -54.98 dBm
# 37. Harmonische: 74.027073 MHz, Leistung: -54.98 dBm
# 38. Harmonische: 95.177665 MHz, Leistung: -12.22 dBm
# 39. Harmonische: 95.177665 MHz, Leistung: -12.22 dBm
# 40. Harmonische: 99.407783 MHz, Leistung: -12.22 dBm
# 41. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 42. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 43. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 44. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 45. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 46. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 47. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 48. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 49. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 50. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 51. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 52. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 53. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
# 54. Harmonische: 101.522843 MHz, Leistung: -12.22 dBm
#
Harmonische: 674.703892 MHz, Leistung: -55.48 dBm
# 326. Harmonische: 674.703892 MHz, Leistung: -55.48 dBm
# 327. Harmonische: 706.429780 MHz, Leistung: -54.98 dBm
# 328. Harmonische: 706.429780 MHz, Leistung: -54.98 dBm
# 329. Harmonische: 706.429780 MHz, Leistung: -54.98 dBm
# 330. Harmonische: 706.429780 MHz, Leistung: -54.98 dBm
# 331. Harmonische: 706.429780 MHz, Leistung: -54.98 dBm
# 332. Harmonische: 706.429780 MHz, Leistung: -54.98 dBm
# 333. Harmonische: 706.429780 MHz, Leistung: -54.98 dBm
# 334. Harmonische: 721.235195 MHz, Leistung: -34.36 dBm
# 335. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 336. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 337. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 338. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 339. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 340. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 341. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 342. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 343. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 344. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 345. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 346. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 347. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 348. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 349. Harmonische: 723.350254 MHz, Leistung: -34.36 dBm
# 350. Harmonische: 725.465313 MHz, Leistung: -34.36 dBm
# 351. Harmonische: 727.580372 MHz, Leistung: -34.36 dBm
# 352. Harmonische: 742.385787 MHz, Leistung: -50.25 dBm
# 353. Harmonische: 742.385787 MHz, Leistung: -50.25 dBm
# 354. Harmonische: 742.385787 MHz, Leistung: -50.25 dBm
# 355. Harmonische: 742.385787 MHz, Leistung: -50.25 dBm
# 356. Harmonische: 742.385787 MHz, Leistung: -50.25 dBm
# 357. Harmonische: 742.385787 MHz, Leistung: -50.25 dBm
# 358. Harmonische: 742.385787 MHz, Leistung: -50.25 dBm
# 359. Harmonische: 744.500846 MHz, Leistung: -55.15 dBm
# 360. Harmonische: 776.226734 MHz, Leistung: -54.74 dBm
# 361. Harmonische: 776.226734 MHz, Leistung: -54.74 dBm
# 362. Harmonische: 780.456853 MHz, Leistung: -54.76 dBm
# 363. Harmonische: 780.456853 MHz, Leistung: -54.76 dBm
# 364. Harmonische: 780.456853 MHz, Leistung: -54.76 dBm
# 365. Harmonische: 780.456853 MHz, Leistung: -54.76 dBm
# 366. Harmonische: 780.456853 MHz, Leistung: -54.76 dBm
# 367. Harmonische: 780.456853 MHz, Leistung: -54.76 dBm
# 368. Harmonische: 780.456853 MHz, Leistung: -54.76 dBm
# 369. Harmonische: 780.456853 MHz, Leistung: -54.76 dBm
# 370. Harmonische: 780.456853 MHz, Leistung: -54.76 dBm
# 371. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 372. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 373. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 374. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 375. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 376. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 377. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 378. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 379. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 380. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 381. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 382. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 383. Harmonische: 799.492386 MHz, Leistung: -54.40 dBm
# 384. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 385. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 386. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 387. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 388. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 389. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 390. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 391. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 392. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 393. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 394. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 395. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 396. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 397. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 398. Harmonische: 826.988156 MHz, Leistung: -43.49 dBm
# 399. Harmonische: 829.103215 MHz, Leistung: -43.50 dBm
# 400. Harmonische: 831.218274 MHz, Leistung: -43.50 dBm
# 401. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 402. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 403. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 404. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 405. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 406. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 407. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 408. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 409. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 410. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 411. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 412. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 413. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 414. Harmonische: 860.829103 MHz, Leistung: -54.02 dBm
# 415. Harmonische: 869.289340 MHz, Leistung: -54.07 dBm
# 416. Harmonische: 869.289340 MHz, Leistung: -54.07 dBm
# 417. Harmonische: 869.289340 MHz, Leistung: -54.07 dBm
# 418. Harmonische: 869.289340 MHz, Leistung: -54.07 dBm
# 419. Harmonische: 901.015228 MHz, Leistung: -54.72 dBm
# 420. Harmonische: 901.015228 MHz, Leistung: -54.72 dBm
# 421. Harmonische: 905.245347 MHz, Leistung: -54.76 dBm
#
Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 532. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 533. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 534. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 535. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 536. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 537. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 538. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 539. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 540. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 541. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 542. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 543. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 544. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 545. Harmonische: 1137.901861 MHz, Leistung: -42.37 dBm
# 546. Harmonische: 1140.016920 MHz, Leistung: -42.37 dBm
# 547. Harmonische: 1142.131980 MHz, Leistung: -42.37 dBm
# 548. Harmonische: 1159.052453 MHz, Leistung: -56.70 dBm
# 549. Harmonische: 1159.052453 MHz, Leistung: -56.70 dBm
# 550. Harmonische: 1159.052453 MHz, Leistung: -56.70 dBm
# 551. Harmonische: 1159.052453 MHz, Leistung: -56.70 dBm
# 552. Harmonische: 1159.052453 MHz, Leistung: -56.70 dBm
# 553. Harmonische: 1159.052453 MHz, Leistung: -56.70 dBm
# 554. Harmonische: 1159.052453 MHz, Leistung: -56.70 dBm
# 555. Harmonische: 1159.052453 MHz, Leistung: -56.70 dBm
# 556. Harmonische: 1190.778342 MHz, Leistung: -57.05 dBm
# 557. Harmonische: 1190.778342 MHz, Leistung: -57.05 dBm
# 558. Harmonische: 1190.778342 MHz, Leistung: -57.05 dBm
# 559. Harmonische: 1190.778342 MHz, Leistung: -57.05 dBm
# 560. Harmonische: 1190.778342 MHz, Leistung: -57.05 dBm
# 561. Harmonische: 1190.778342 MHz, Leistung: -57.05 dBm
# 562. Harmonische: 1190.778342 MHz, Leistung: -57.05 dBm
# 563. Harmonische: 1205.583756 MHz, Leistung: -56.86 dBm
# 564. Harmonische: 1205.583756 MHz, Leistung: -56.86 dBm
# 565. Harmonische: 1205.583756 MHz, Leistung: -56.86 dBm
# 566. Harmonische: 1205.583756 MHz, Leistung: -56.86 dBm
# 567. Harmonische: 1205.583756 MHz, Leistung: -56.86 dBm
# 568. Harmonische: 1205.583756 MHz, Leistung: -56.86 dBm
# 569. Harmonische: 1205.583756 MHz, Leistung: -56.86 dBm
# 570. Harmonische: 1220.389171 MHz, Leistung: -57.01 dBm
# 571. Harmonische: 1220.389171 MHz, Leistung: -57.01 dBm
# 572. Harmonische: 1220.389171 MHz, Leistung: -57.01 dBm
# 573. Harmonische: 1220.389171 MHz, Leistung: -57.01 dBm
# 574. Harmonische: 1220.389171 MHz, Leistung: -57.01 dBm
# 575. Harmonische: 1220.389171 MHz, Leistung: -57.01 dBm
# 576. Harmonische: 1220.389171 MHz, Leistung: -57.01 dBm
# 577. Harmonische: 1220.389171 MHz, Leistung: -57.01 dBm
# 578. Harmonische: 1220.389171 MHz, Leistung: -57.01 dBm
# 579. Harmonische: 1220.389171 MHz, Leistung: -57.01 dBm
# 580. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 581. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 582. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 583. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 584. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 585. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 586. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 587. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 588. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 589. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 590. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 591. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 592. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 593. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 594. Harmonische: 1241.539763 MHz, Leistung: -48.97 dBm
# 595. Harmonische: 1243.654822 MHz, Leistung: -48.95 dBm
# 596. Harmonische: 1245.769882 MHz, Leistung: -48.96 dBm
# 597. Harmonische: 1252.115059 MHz, Leistung: -48.96 dBm
# 598. Harmonische: 1252.115059 MHz, Leistung: -48.96 dBm
# 599. Harmonische: 1252.115059 MHz, Leistung: -48.96 dBm
# 600. Harmonische: 1266.920474 MHz, Leistung: -56.93 dBm
# 601. Harmonische: 1266.920474 MHz, Leistung: -56.93 dBm
# 602. Harmonische: 1266.920474 MHz, Leistung: -56.93 dBm
# 603. Harmonische: 1266.920474 MHz, Leistung: -56.93 dBm
# 604. Harmonische: 1266.920474 MHz, Leistung: -56.93 dBm
# 605. Harmonische: 1266.920474 MHz, Leistung: -56.93 dBm
# 606. Harmonische: 1266.920474 MHz, Leistung: -56.93 dBm
# 607. Harmonische: 1275.380711 MHz, Leistung: -56.87 dBm
# 608. Harmonische: 1275.380711 MHz, Leistung: -56.87 dBm
# 609. Harmonische: 1275.380711 MHz, Leistung: -56.87 dBm
# 610. Harmonische: 1275.380711 MHz, Leistung: -56.87 dBm
# 611. Harmonische: 1288.071066 MHz, Leistung: -57.13 dBm
# 612. Harmonische: 1288.071066 MHz, Leistung: -57.13 dBm
# 613. Harmonische: 1288.071066 MHz, Leistung: -57.13 dBm
# 614. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 615. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 616. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 617. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 618. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 619. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 620. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 621. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 622. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 623. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 624. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 625. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 626. Harmonische: 1313.451777 MHz, Leistung: -57.01 dBm
# 627. Harmonische: 1340.947547 MHz, Leistung: -47.13 dBm
# 628. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 629. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 630. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 631. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 632. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 633. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 634. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 635. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 636. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 637. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 638. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 639. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 640. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 641. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 642. Harmonische: 1343.062606 MHz, Leistung: -47.13 dBm
# 643. Harmonische: 1345.177665 MHz, Leistung: -47.12 dBm
# 644. Harmonische: 1347.292724 MHz, Leistung: -47.11 dBm
# 645. Harmonische: 1368.443316 MHz, Leistung: -56.40 dBm
# 646. Harmonische: 1368.443316 MHz, Leistung: -56.40 dBm
# 647. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 648. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 649. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 650. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 651. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 652. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 653. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 654. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 655. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 656. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 657. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 658. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 659. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 660. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 661. Harmonische: 1383.248731 MHz, Leistung: -56.25 dBm
# 662. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 663. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 664. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 665. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 666. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 667. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 668. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 669. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 670. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 671. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 672. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 673. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 674. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 675. Harmonische: 1412.859560 MHz, Leistung: -56.74 dBm
# 676. Harmonische: 1429.780034 MHz, Leistung: -56.69 dBm
# 677. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 678. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 679. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 680. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 681. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 682. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 683. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 684. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 685. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 686. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 687. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 688. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 689. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 690. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 691. Harmonische: 1446.700508 MHz, Leistung: -52.24 dBm
# 692. Harmonische: 1448.815567 MHz, Leistung: -52.28 dBm
# 693. Harmonische: 1450.930626 MHz, Leistung: -52.25 dBm
# 694. Harmonische: 1465.736041 MHz, Leistung: -56.42 dBm
# 695. Harmonische: 1465.736041 MHz, Leistung: -56.42 dBm
# 696. Harmonische: 1465.736041 MHz, Leistung: -56.42 dBm
# 697. Harmonische: 1465.736041 MHz, Leistung: -56.42 dBm
# 698. Harmonische: 1465.736041 MHz, Leistung: -56.42 dBm
# 699. Harmonische: 1493.231810 MHz, Leistung: -56.27 dBm
# 700. Harmonische: 1493.231810 MHz, Leistung: -56.27 dBm
# 701. Harmonische: 1493.231810 MHz, Leistung: -56.27 dBm
# 702. Harmonische: 1493.231810 MHz, Leistung: -56.27 dBm
# 703. Harmonische: 1493.231810 MHz, Leistung: -56.27 dBm
# 704. Harmonische: 1493.231810 MHz, Leistung: -56.27 dBm
# 705. Harmonische: 1493.231810 MHz, Leistung: -56.27 dBm
# 706. Harmonische: 1493.231810 MHz, Leistung: -56.27 dBm
# 707. Harmonische: 1493.231810 MHz, Leistung: -56.27 dBm
# 708. Harmonische: 1493.231810 MHz, Leistung: -56.27 dBm
# 709. Harmonische: 1514.382403 MHz, Leistung: -55.94 dBm
# 710. Harmonische: 1514.382403 MHz, Leistung: -55.94 dBm
# 711. Harmonische: 1514.382403 MHz, Leistung: -55.94 dBm
# 712. Harmonische: 1514.382403 MHz, Leistung: -55.94 dBm
# 713. Harmonische: 1514.382403 MHz, Leistung: -55.94 dBm
# 714. Harmonische: 1514.382403 MHz, Leistung: -55.94 dBm
# 715. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 716. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 717. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 718. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 719. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 720. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 721. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 722. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 723. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 724. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 725. Harmonische: 1527.072758 MHz, Leistung: -56.01 dBm
# 726. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 727. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 728. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 729. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 730. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 731. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 732. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 733. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 734. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 735. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 736. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 737. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 738. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 739. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 740. Harmonische: 1550.338409 MHz, Leistung: -50.62 dBm
# 741. Harmonische: 1552.453469 MHz, Leistung: -50.61 dBm
# 742. Harmonische: 1554.568528 MHz, Leistung: -50.62 dBm
# 743. Harmonische: 1571.489002 MHz, Leistung: -56.03 dBm
# 744. Harmonische: 1571.489002 MHz, Leistung: -56.03 dBm
# 745. Harmonische: 1571.489002 MHz, Leistung: -56.03 dBm
# 746. Harmonische: 1571.489002 MHz, Leistung: -56.03 dBm
# 747. Harmonische: 1571.489002 MHz, Leistung: -56.03 dBm
# 748. Harmonische: 1571.489002 MHz, Leistung: -56.03 dBm
# 749. Harmonische: 1571.489002 MHz, Leistung: -56.03 dBm
# 750. Harmonische: 1571.489002 MHz, Leistung: -56.03 dBm
# 751. Harmonische: 1590.524535 MHz, Leistung: -56.01 dBm
# 752. Harmonische: 1590.524535 MHz, Leistung: -56.01 dBm
# 753. Harmonische: 1590.524535 MHz, Leistung: -56.01 dBm
# 754. Harmonische: 1590.524535 MHz, Leistung: -56.01 dBm
# 755. Harmonische: 1590.524535 MHz, Leistung: -56.01 dBm
# 756. Harmonische: 1590.524535 MHz, Leistung: -56.01 dBm
# 757. Harmonische: 1590.524535 MHz, Leistung: -56.01 dBm
# 758. Harmonische: 1590.524535 MHz, Leistung: -56.01 dBm
# 759. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 760. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 761. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 762. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 763. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 764. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 765. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 766. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 767. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 768. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 769. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 770. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 771. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 772. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 773. Harmonische: 1620.135364 MHz, Leistung: -55.98 dBm
# 774. Harmonische: 1641.285956 MHz, Leistung: -51.31 dBm
# 775. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 776. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 777. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 778. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 779. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 780. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 781. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 782. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 783. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 784. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 785. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 786. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 787. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 788. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 789. Harmonische: 1653.976311 MHz, Leistung: -51.20 dBm
# 790. Harmonische: 1656.091371 MHz, Leistung: -51.19 dBm
# 791. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 792. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 793. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 794. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 795. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 796. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 797. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 798. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 799. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 800. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 801. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 802. Harmonische: 1681.472081 MHz, Leistung: -54.78 dBm
# 803. Harmonische: 1683.587140 MHz, Leistung: -54.84 dBm
# 804. Harmonische: 1692.047377 MHz, Leistung: -55.03 dBm
# 805. Harmonische: 1717.428088 MHz, Leistung: -55.34 dBm
# 806. Harmonische: 1717.428088 MHz, Leistung: -55.34 dBm
# 807. Harmonische: 1717.428088 MHz, Leistung: -55.34 dBm
# 808. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 809. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 810. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 811. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 812. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 813. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 814. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 815. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 816. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 817. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 818. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 819. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 820. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 821. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 822. Harmonische: 1723.773266 MHz, Leistung: -55.08 dBm
# 823. Harmonische: 1744.923858 MHz, Leistung: -50.82 dBm
# 824. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 825. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 826. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 827. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 828. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 829. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 830. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 831. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 832. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 833. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 834. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 835. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 836. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 837. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 838. Harmonische: 1757.614213 MHz, Leistung: -50.84 dBm
# 839. Harmonische: 1759.729272 MHz, Leistung: -50.86 dBm
# 840. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 841. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 842. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 843. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 844. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 845. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 846. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 847. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 848. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 849. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 850. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 851. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 852. Harmonische: 1791.455161 MHz, Leistung: -54.85 dBm
# 853. Harmonische: 1818.950931 MHz, Leistung: -54.20 dBm
# 854. Harmonische: 1818.950931 MHz, Leistung: -54.20 dBm
# 855. Harmonische: 1818.950931 MHz, Leistung: -54.20 dBm
# 856. Harmonische: 1818.950931 MHz, Leistung: -54.20 dBm
# 857. Harmonische: 1818.950931 MHz, Leistung: -54.20 dBm
# 858. Harmonische: 1829.526227 MHz, Leistung: -54.22 dBm
# 859. Harmonische: 1829.526227 MHz, Leistung: -54.22 dBm
# 860. Harmonische: 1829.526227 MHz, Leistung: -54.22 dBm
# 861. Harmonische: 1829.526227 MHz, Leistung: -54.22 dBm
# 862. Harmonische: 1829.526227 MHz, Leistung: -54.22 dBm
# ...
# 912. Harmonische: 1926.818951 MHz, Leistung: -53.65 dBm
# 913. Harmonische: 1926.818951 MHz, Leistung: -53.65 dBm
# 914. Harmonische: 1926.818951 MHz, Leistung: -53.65 dBm
# 915. Harmonische: 1926.818951 MHz, Leistung: -53.65 dBm
# 916. Harmonische: 1926.818951 MHz, Leistung: -53.65 dBm
# 917. Harmonische: 1926.818951 MHz, Leistung: -53.65 dBm
# 918. Harmonische: 1926.818951 MHz, Leistung: -53.65 dBm
# 919. Harmonische: 1935.279188 MHz, Leistung: -53.85 dBm
# 920. Harmonische: 1935.279188 MHz, Leistung: -53.85 dBm
# 921. Harmonische: 1962.774958 MHz, Leistung: -52.35 dBm
# 922. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 923. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 924. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 925. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 926. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 927. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 928. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 929. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 930. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 931. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 932. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 933. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 934. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 935. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 936. Harmonische: 1964.890017 MHz, Leistung: -52.28 dBm
# 937. Harmonische: 1967.005076 MHz, Leistung: -52.28 dBm
# 938. Harmonische: 1969.120135 MHz, Leistung: -52.28 dBm
# 939. Harmonische: 1971.235195 MHz, Leistung: -52.26 dBm
# 940. Harmonische: 1992.385787 MHz, Leistung: -54.25 dBm
# 941. Harmonische: 1992.385787 MHz, Leistung: -54.25 dBm
# 942. Harmonische: 1992.385787 MHz, Leistung: -54.25 dBm
# 943. Harmonische: 2009.306261 MHz, Leistung: -54.10 dBm
# 944. Harmonische: 2009.306261 MHz, Leistung: -54.10 dBm
# 945. Harmonische: 2009.306261 MHz, Leistung: -54.10 dBm
# 946. Harmonische: 2009.306261 MHz, Leistung: -54.10 dBm
# 947. Harmonische: 2009.306261 MHz, Leistung: -54.10 dBm
# 948. Harmonische: 2009.306261 MHz, Leistung: -54.10 dBm
# 949. Harmonische: 2009.306261 MHz, Leistung: -54.10 dBm
# 950. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 951. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 952. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 953. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 954. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 955. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 956. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 957. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 958. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 959. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 960. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 961. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 962. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 963. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 964. Harmonische: 2024.111675 MHz, Leistung: -53.67 dBm
# 965. Harmonische: 2047.377327 MHz, Leistung: -53.98 dBm
# 966. Harmonische: 2047.377327 MHz, Leistung: -53.98 dBm
# 967. Harmonische: 2047.377327 MHz, Leistung: -53.98 dBm
# 968. Harmonische: 2062.182741 MHz, Leistung: -52.25 dBm
# 969. Harmonische: 2062.182741 MHz, Leistung: -52.25 dBm
# 970. Harmonische: 2062.182741 MHz, Leistung: -52.25 dBm
# 971. Harmonische: 2068.527919 MHz, Leistung: -52.10 dBm
# 972. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 973. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 974. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 975. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 976. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 977. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 978. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 979. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 980. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 981. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 982. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 983. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 984. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 985. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 986. Harmonische: 2070.642978 MHz, Leistung: -52.13 dBm
# 987. Harmonische: 2083.333333 MHz, Leistung: -52.14 dBm
# 988. Harmonische: 2083.333333 MHz, Leistung: -52.14 dBm
# 989. Harmonische: 2083.333333 MHz, Leistung: -52.14 dBm
# 990. Harmonische: 2083.333333 MHz, Leistung: -52.14 dBm
# 991. Harmonische: 2083.333333 MHz, Leistung: -52.14 dBm
# 992. Harmonische: 2083.333333 MHz, Leistung: -52.14 dBm
# 993. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 994. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 995. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 996. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 997. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 998. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 999. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 1000. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 1001. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 1002. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 1003. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 1004. Harmonische: 2108.714044 MHz, Leistung: -54.08 dBm
# 1005. Harmonische: 2119.289340 MHz, Leistung: -54.06 dBm
# 1006. Harmonische: 2119.289340 MHz, Leistung: -54.06 dBm
# 1007. Harmonische: 2119.289340 MHz, Leistung: -54.06 dBm
# 1008. Harmonische: 2119.289340 MHz, Leistung: -54.06 dBm
# 1009. Harmonische: 2119.289340 MHz, Leistung: -54.06 dBm
# 1010. Harmonische: 2142.554992 MHz, Leistung: -54.29 dBm
# 1011. Harmonische: 2142.554992 MHz, Leistung: -54.29 dBm
# 1012. Harmonische: 2142.554992 MHz, Leistung: -54.29 dBm
# 1013. Harmonische: 2142.554992 MHz, Leistung: -54.29 dBm
# 1014. Harmonische: 2142.554992 MHz, Leistung: -54.29 dBm
# 1015. Harmonische: 2142.554992 MHz, Leistung: -54.29 dBm
# 1016. Harmonische: 2142.554992 MHz, Leistung: -54.29 dBm
# 1017. Harmonische: 2142.554992 MHz, Leistung: -54.29 dBm
# 1018. Harmonische: 2142.554992 MHz, Leistung: -54.29 dBm
# 1019. Harmonische: 2142.554992 MHz, Leistung: -54.29 dBm
# 1020. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1021. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1022. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1023. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1024. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1025. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1026. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1027. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1028. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1029. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1030. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1031. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1032. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1033. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1034. Harmonische: 2172.165821 MHz, Leistung: -53.02 dBm
# 1035. Harmonische: 2174.280880 MHz, Leistung: -53.11 dBm
# 1036. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1037. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1038. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1039. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1040. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1041. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1042. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1043. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1044. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1045. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1046. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1047. Harmonische: 2201.776650 MHz, Leistung: -54.75 dBm
# 1048. Harmonische: 2231.387479 MHz, Leistung: -53.76 dBm
# 1049. Harmonische: 2231.387479 MHz, Leistung: -53.76 dBm
# 1050. Harmonische: 2231.387479 MHz, Leistung: -53.76 dBm
# 1051. Harmonische: 2231.387479 MHz, Leistung: -53.76 dBm
# 1052. Harmonische: 2231.387479 MHz, Leistung: -53.76 dBm
# 1053. Harmonische: 2231.387479 MHz, Leistung: -53.76 dBm
# 1054. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1055. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1056. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1057. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1058. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1059. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1060. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1061. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1062. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1063. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1064. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1065. Harmonische: 2244.077834 MHz, Leistung: -53.62 dBm
# 1066. Harmonische: 2269.458545 MHz, Leistung: -52.71 dBm
# 1067. Harmonische: 2269.458545 MHz, Leistung: -52.71 dBm
# 1068. Harmonische: 2269.458545 MHz, Leistung: -52.71 dBm
# 1069. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1070. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1071. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1072. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1073. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1074. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1075. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1076. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1077. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1078. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1079. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1080. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1081. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1082. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1083. Harmonische: 2275.803723 MHz, Leistung: -52.69 dBm
# 1084. Harmonische: 2277.918782 MHz, Leistung: -52.70 dBm
# 1085. Harmonische: 2301.184433 MHz, Leistung: -53.83 dBm
# 1086. Harmonische: 2301.184433 MHz, Leistung: -53.83 dBm
# 1087. Harmonische: 2301.184433 MHz, Leistung: -53.83 dBm
# 1088. Harmonische: 2301.184433 MHz, Leistung: -53.83 dBm
# 1089. Harmonische: 2301.184433 MHz, Leistung: -53.83 dBm
# 1090. Harmonische: 2301.184433 MHz, Leistung: -53.83 dBm
# 1091. Harmonische: 2301.184433 MHz, Leistung: -53.83 dBm
# 1092. Harmonische: 2301.184433 MHz, Leistung: -53.83 dBm
# 1093. Harmonische: 2301.184433 MHz, Leistung: -53.83 dBm
# 1094. Harmonische: 2301.184433 MHz, Leistung: -53.83 dBm
Harmonische: 2483.079526 MHz, Leistung: -52.64 dBm
# 1181. Harmonische: 2483.079526 MHz, Leistung: -52.64 dBm
# 1182. Harmonische: 2485.194585 MHz, Leistung: -52.45 dBm
# /Users/johannes/Library/CloudStorage/OneDrive-FHJOANNEUM/Kommunikationstechnologien/KT-course/KT-course/.venv/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/johannes/Library/CloudStorage/OneDrive-FHJOANNEUM/Kommunikationstechnologien/KT-course/KT-course/.venv/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Screenshot vom Gerät lesen und anzeigen
#
# Hardcopy (PNG) auf dem FPC auslösen, dann Datei per MMEM:DATA? lesen und hier anzeigen.
#
# ### ACHTUNG:
# Die Screenshot-Funktion dauert bis zu 10 Sekunden ! Solange wird auch die Zelle ausgeführt, was aus dem [*] -Symbol links der Zelle ersichtlich ist.

# %%
SCREENSHOT_FILENAME = "screen.png"
SCREENSHOT_DIR.mkdir(parents=True, exist_ok=True)

if REPLAY:
    replay = load_replay_json(REPLAY_FILE)
    shot_path_str = replay.get("screenshot_path", "")
    shot_path = Path(shot_path_str) if shot_path_str else None

    if shot_path and shot_path.exists():
        print("Replay-Screenshot geladen:", shot_path)
        display(Image(filename=str(shot_path)))
    else:
        print("REPLAY=True: Kein gueltiger screenshot_path in Replay-Datei vorhanden.")
        if shot_path_str:
            print("Gespeicherter Pfad (nicht gefunden):", shot_path_str)
else:
    err = screenshot_save(FPC_IP, FPC_PORT, SCREENSHOT_FILENAME)
    if err:
        print("Screenshot (HCOP) Fehler:", err)
    else:
        png_bytes = screenshot_read(FPC_IP, FPC_PORT, SCREENSHOT_FILENAME)
        if png_bytes:
            path = SCREENSHOT_DIR / f"{REPLAY_FILE.stem.replace('_replay', '')}_screenshot.png"
            path.write_bytes(png_bytes)
            print("Gespeichert (Laborprotokoll):", path.resolve())
            display(Image(data=png_bytes))

            # Screenshot-Verweis im Replay-JSON ablegen
            try:
                replay = load_replay_json(REPLAY_FILE) if REPLAY_FILE.exists() else {}
                replay["screenshot_path"] = str(path)
                save_replay_json(REPLAY_FILE, replay)
                print("Replay aktualisiert mit screenshot_path:", REPLAY_FILE)
            except Exception as ex:
                print("Hinweis: screenshot_path konnte nicht im Replay gespeichert werden:", ex)
        else:
            print("Screenshot auf Geraet gespeichert; Anzeige (MMEM:DATA?) nicht moeglich oder nicht unterstuetzt.")
# Out:
# Replay-Screenshot geladen: screenshots\1-fpc1500_sa_screenshot.png

# %% [markdown]
# **Notebook exportieren (Laborprotokoll):** Über *File → Save and Export Notebook As…* bzw. **nbconvert** exportierbar als **HTML** (mit Ausgaben/Bildern), **PDF** oder **LaTeX**. Screenshots liegen dauerhaft im Ordner `screenshots/`.

# %%
# Platzhalter für eventuelle Kommentare

# %% [markdown]
# Der Screenshot zeigt das gemessene Spektrum des FPC1500 im Bereich von 0 Hz bis 2,5 GHz.
# Die stärkste Spektrallinie liegt bei ca. 95,7 MHz mit einem Pegel von etwa -66,6 dBm.
# Weitere Spektrallinien treten bei ganzzahligen Vielfachen der Grundfrequenz auf und entsprechen den Harmonischen des Signals.
# Der Rauschboden liegt deutlich unterhalb der Signalspitzen. Dadurch sind Grundschwingung und Oberwellen klar vom Rauschen unterscheidbar.
